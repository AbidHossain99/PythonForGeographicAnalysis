# %%
import pandas as pd

# %%
data = pd.read_csv("USW00094724.csv", skiprows=8)

# %%
data.head(10)
# Out:
#    USW00094724  2002-12  5.2   ,W  256.0    W    0.0 ,W.1    13 ,W.2  ...  \
# 0  USW00094724  2003-01  5.5   ,W    0.0    W    0.0   ,W  11.0   ,W  ...
# 1  USW00094724  2003-02  5.3   ,W    0.0    W    0.0   ,W  10.0   ,W  ...
# 2  USW00094724  2003-03  4.7   ,W    0.0    W    0.0   ,W   8.0   ,W  ...
# 3  USW00094724  2003-04  5.6   ,W    0.0    W    0.0   ,W  11.0   ,W  ...
# 4  USW00094724  2003-05  4.4   ,W    0.0    W    0.0   ,W  13.0   ,W  ...
# 5  USW00094724  2003-06  3.7   ,W    NaN  NaN    NaN  NaN  15.0   ,W  ...
# 6  USW00094724  2003-07  3.9   ,W    NaN  NaN   81.2   ,W  11.0   ,W  ...
# 7  USW00094724  2003-08  4.0   ,W    NaN  NaN  128.5   ,W  10.0  4,W  ...
# 8  USW00094724  2003-09  NaN  NaN    NaN  NaN    NaN  NaN   8.0  5,W  ...
# 9  USW00094724  2003-10  4.5   ,W    NaN  NaN    0.0   ,W  12.0   ,W  ...
#
#    0.3 ,W.12    330 ,W.13  330.1 ,W.14  15.6 ,W.15  21.0 ,W.16
# 0  0.0   1,W   20.0    ,W   10.0    ,W  16.1    ,W  19.7    ,W
# ...

# %%
data.tail()
# Out:
#      USW00094724  2002-12  5.2   ,W  256.0    W    0.0 ,W.1    13 ,W.2  ...  \
# 196  USW00094724  2019-06  3.7   ,W    NaN  NaN   19.4   ,W  14.0   ,W  ...
# 197  USW00094724  2019-07  3.2   ,W    NaN  NaN  123.7   ,W   6.0   ,W  ...
# 198  USW00094724  2019-08  3.3   ,W    NaN  NaN   85.6   ,W  10.0  3,W  ...
# 199  USW00094724  2019-09  3.8   ,W    NaN  NaN   13.4   ,W   9.0   ,W  ...
# 200  USW00094724  2019-10  5.1  2,W    NaN  NaN    5.3  2,W  15.0  2,W  ...
#
#      0.3 ,W.12    330 ,W.13  330.1 ,W.14  15.6 ,W.15  21.0 ,W.16
# 196  NaN   NaN  350.0    ,W   10.0    ,W  13.4    ,W  21.0    ,W
# 197  NaN   NaN  170.0    ,W  200.0    ,W   9.8    ,W  14.3    ,W
# 198  NaN   NaN   40.0    ,W  210.0    ,W  11.2    ,W  15.2    ,W
# 199  NaN   NaN   60.0    ,W   60.0    ,W  15.7    ,W  19.7    ,W
# 200  NaN   NaN  120.0   2,W  120.0   2,W  20.6   2,W  27.7   2,W
#
# [5 rows x 64 columns]

# %%
len(data)
# Out:
# 253

# %%
data.shape
# Out:
# (253, 64)

# %%
data.columns.values
# Out:
# array(['USW00094724', '1998-08', '3.2', ',W', '125.4', 'W', '54.1',
#        ',W.1', '14', ',W.2', '7', ',W.3', '2', ',W.4', '0', ',W.5', '0.1',
#        ',W.6', '0.2', ',W.7', '30', ',W.8', '0.3', ',W.9', '19980820',
#        '+,,W', '19980811', ',,W', '19980818', ',,W.1', '6.1', ',W,20,+',
#        '30.5', ',,W,11,', '28.9', ',W,18,', '35.6', 'W.1', '18.7',
#        ',W.10', 'Unnamed: 40', 'Unnamed: 41', 'Unnamed: 42',
#        'Unnamed: 43', 'Unnamed: 44', 'Unnamed: 45', '110.2', ',,,W',
#        '19.47', ',W.11', '25.28', ',,,W.1', '13.67', ',,,W.2',
#        'Unnamed: 54', 'Unnamed: 55', '210', ',W.12', '200', ',W.13',
#        '11.2', ',W.14', '14.8', ',W.15'], dtype=object)

# %%
data.index
# Out:
# RangeIndex(start=0, stop=253, step=1)

# %%
data.dtypes
# Out:
# USW00094724     object
# 1998-08         object
# 3.2            float64
# ,W              object
# 125.4          float64
#                 ...
# ,W.13           object
# 11.2           float64
# ,W.14           object
# 14.8           float64
# ,W.15           object
# Length: 64, dtype: object

# %%
selection = data[["USW00094724","1998-08"]]
selection.head()
# Out:
#    USW00094724  1998-08
# 0  USW00094724  1998-09
# 1  USW00094724  1998-10
# 2  USW00094724  1998-11
# 3  USW00094724  1998-12
# 4  USW00094724  1999-01

# %%
data["1998-08"].head()
# Out:
# 0    1998-09
# 1    1998-10
# 2    1998-11
# 3    1998-12
# 4    1999-01
# Name: 1998-08, dtype: object

# %%
data["1998-08"].unique()
# Out:
# array(['1998-09', '1998-10', '1998-11', '1998-12', '1999-01', '1999-02',
#        '1999-03', '1999-04', '1999-05', '1999-06', '1999-07', '1999-08',
#        '1999-09', '1999-10', '1999-11', '1999-12', '2000-01', '2000-02',
#        '2000-03', '2000-04', '2000-05', '2000-06', '2000-07', '2000-08',
#        '2000-09', '2000-10', '2000-11', '2000-12', '2001-01', '2001-02',
#        '2001-03', '2001-04', '2001-05', '2001-06', '2001-07', '2001-08',
#        '2001-09', '2001-10', '2001-11', '2001-12', '2002-01', '2002-02',
#        '2002-03', '2002-04', '2002-05', '2002-06', '2002-07', '2002-08',
#        '2002-09', '2002-10', '2002-11', '2002-12', '2003-01', '2003-02',
#        '2003-03', '2003-04', '2003-05', '2003-06', '2003-07', '2003-08',
#        '2003-09', '2003-10', '2003-11', '2003-12', '2004-01', '2004-02',
#        '2004-03', '2004-04', '2004-05', '2004-06', '2004-07', '2004-08',
#        '2004-09', '2004-10', '2004-11', '2004-12', '2005-01', '2005-02',
# ...

# %%
data.mean()
# Out:
# <ipython-input-27-abc01cf6c622>:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   data.mean()
# 3.2            4.499203e+00
# 125.4          1.148339e+02
# 54.1           2.270082e+01
# 14             1.127092e+01
# 7              5.992032e+00
# 2              8.725100e-01
# 0              7.755102e-02
# 0.1            9.379592e+00
# 0.2            1.351020e+00
# 30             1.011020e+01
# 0.3            1.836735e-01
# 19980820       2.008622e+07
# 19980811       2.008720e+07
# 19980818       2.008622e+07
# 6.1           -4.214694e+00
# 30.5           3.117171e+01
# 28.9           2.270857e+01
# 35.6           1.363246e+03
# 18.7           2.615951e+02
# Unnamed: 40    1.616514e+01
# Unnamed: 41             NaN
# Unnamed: 42    5.598039e+00
# Unnamed: 43             NaN
# Unnamed: 44    2.152174e+00
# ...

# %%
data.describe()
# Out:
#               3.2       125.4        54.1          14           7           2  \
# count  251.000000  218.000000  245.000000  251.000000  251.000000  251.000000
# mean     4.499203  114.833945   22.700816   11.270916    5.992032    0.872510
# std      0.691664  127.577142   39.112977    3.441847    2.507576    0.971433
# min      3.000000    0.000000    0.000000    3.000000    0.000000    0.000000
# 25%      3.900000    0.000000    0.000000    9.000000    4.000000    0.000000
# 50%      4.500000   55.550000    0.000000   11.000000    6.000000    1.000000
# 75%      5.050000  220.800000   29.000000   13.000000    7.000000    1.000000
# max      6.200000  438.400000  188.200000   21.000000   17.000000    5.000000
#
#                 0         0.1         0.2          30  ...  Unnamed: 45  \
# count  245.000000  245.000000  245.000000  245.000000  ...          0.0
# mean     0.077551    9.379592    1.351020   10.110204  ...          NaN
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 253 entries, 0 to 252
# Data columns (total 64 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   USW00094724  253 non-null    object
#  1   1998-08      253 non-null    object
#  2   3.2          251 non-null    float64
#  3   ,W           251 non-null    object
#  4   125.4        218 non-null    float64
#  5   W            216 non-null    object
#  6   54.1         245 non-null    float64
#  7   ,W.1         245 non-null    object
#  8   14           251 non-null    float64
#  9   ,W.2         251 non-null    object
#  10  7            251 non-null    float64
#  11  ,W.3         251 non-null    object
#  12  2            251 non-null    float64
#  13  ,W.4         251 non-null    object
#  14  0            245 non-null    float64
#  15  ,W.5         245 non-null    object
#  16  0.1          245 non-null    float64
#  17  ,W.6         245 non-null    object
# ...

# %%
number_series = pd.Series([4, 5, 6, 7.0])
print(number_series)
# Out:
# 0    4.0
# 1    5.0
# 2    6.0
# 3    7.0
# dtype: float64

# %%
number_series = pd.Series([4, 5, 6, 7.0], index=["a", "b", "c", "d"])
print(number_series)
# Out:
# a    4.0
# b    5.0
# c    6.0
# d    7.0
# dtype: float64

# %%
stations = ["Hanko", "Heinola", "Kaisaniemi", "Malmi"]
latitudes = [59.77, 61.2, 60.18, 60.25]
longitudes = [22.95, 26.05, 24.94, 25.05]

# %%
new_data = pd.DataFrame(data={"station": stations, "lat": latitudes, "lon": longitudes})
new_data
# Out:
#       station    lat    lon
# 0       Hanko  59.77  22.95
# 1     Heinola  61.20  26.05
# 2  Kaisaniemi  60.18  24.94
# 3       Malmi  60.25  25.05

# %%
dictionaries = [
    {"station": "Hanko", "lat": 59.77, "lon": 22.95},
    {"station": "Heinola", "lat": 61.2, "lon": 26.05},
    {"station": "Kaisaniemi", "lat": 60.18, "lon": 24.94},
    {"station": "Malmi", "lat": 60.25, "lon": 25.05},
]

new_data_2 = pd.DataFrame(dictionaries)
new_data_2
# Out:
#       station    lat    lon
# 0       Hanko  59.77  22.95
# 1     Heinola  61.20  26.05
# 2  Kaisaniemi  60.18  24.94
# 3       Malmi  60.25  25.05

# %%
df = pd.DataFrame()
print(df)
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
df["lon"] = longitudes
df["lat"] = latitudes
df
# Out:
#      lon    lat
# 0  22.95  59.77
# 1  26.05  61.20
# 2  24.94  60.18
# 3  25.05  60.25

# %% [markdown]
# ### **Common tabular operations in pandas**

# %%
data["DIFF"] = 0.0
data.head()
# Out:
#    USW00094724  1998-08  3.2  ,W  125.4  W  54.1 ,W.1    14 ,W.2  ...  \
# 0  USW00094724  1998-09  3.7  ,W  143.1  W  17.7   ,W  12.0   ,W  ...
# 1  USW00094724  1998-10  4.7  ,W  143.1  W   0.0   ,W   8.0   ,W  ...
# 2  USW00094724  1998-11  4.5  ,W  143.1  W   0.0   ,W   5.0   ,W  ...
# 3  USW00094724  1998-12  4.4  ,W  143.1  W   0.0  1,W   9.0   ,W  ...
# 4  USW00094724  1999-01  5.2  ,W    0.0  W   0.0   ,W  14.0   ,W  ...
#
#    Unnamed: 55    210  ,W.12    200  ,W.13  11.2  ,W.14  14.8  ,W.15 DIFF
# 0          NaN  280.0     ,W  280.0     ,W  13.0     ,W  16.5     ,W  0.0
# 1          NaN  310.0     ,W  310.0     ,W  13.0     ,W  17.4     ,W  0.0
# 2          NaN  190.0     ,W  150.0     ,W  15.2     ,W  20.1     ,W  0.0
# 3          NaN  310.0     ,W  290.0     ,W  14.3     ,W  17.9     ,W  0.0
# 4          NaN  190.0     ,W  190.0     ,W  20.6     ,W  26.8     ,W  0.0
#
# [5 rows x 65 columns]

# %%
data["DIFF"].dtypes
# Out:
# dtype('float64')

# %%
data["DIFF"] = data["3.2"] - data["54.1"]
data.head()
# Out:
#    USW00094724  1998-08  3.2  ,W  125.4  W  54.1 ,W.1    14 ,W.2  ...  \
# 0  USW00094724  1998-09  3.7  ,W  143.1  W  17.7   ,W  12.0   ,W  ...
# 1  USW00094724  1998-10  4.7  ,W  143.1  W   0.0   ,W   8.0   ,W  ...
# 2  USW00094724  1998-11  4.5  ,W  143.1  W   0.0   ,W   5.0   ,W  ...
# 3  USW00094724  1998-12  4.4  ,W  143.1  W   0.0  1,W   9.0   ,W  ...
# 4  USW00094724  1999-01  5.2  ,W    0.0  W   0.0   ,W  14.0   ,W  ...
#
#    Unnamed: 55    210  ,W.12    200  ,W.13  11.2  ,W.14  14.8  ,W.15  DIFF
# 0          NaN  280.0     ,W  280.0     ,W  13.0     ,W  16.5     ,W -14.0
# 1          NaN  310.0     ,W  310.0     ,W  13.0     ,W  17.4     ,W   4.7
# 2          NaN  190.0     ,W  150.0     ,W  15.2     ,W  20.1     ,W   4.5
# 3          NaN  310.0     ,W  290.0     ,W  14.3     ,W  17.9     ,W   4.4
# 4          NaN  190.0     ,W  190.0     ,W  20.6     ,W  26.8     ,W   5.2
#
# [5 rows x 65 columns]

# %%
data["TEMP_CELSIUS"] = (data["DIFF"] - 32) / (9 / 5)
data.head()
# Out:
#    USW00094724  1998-08  3.2  ,W  125.4  W  54.1 ,W.1    14 ,W.2  ...    210  \
# 0  USW00094724  1998-09  3.7  ,W  143.1  W  17.7   ,W  12.0   ,W  ...  280.0
# 1  USW00094724  1998-10  4.7  ,W  143.1  W   0.0   ,W   8.0   ,W  ...  310.0
# 2  USW00094724  1998-11  4.5  ,W  143.1  W   0.0   ,W   5.0   ,W  ...  190.0
# 3  USW00094724  1998-12  4.4  ,W  143.1  W   0.0  1,W   9.0   ,W  ...  310.0
# 4  USW00094724  1999-01  5.2  ,W    0.0  W   0.0   ,W  14.0   ,W  ...  190.0
#
#   ,W.12    200 ,W.13  11.2 ,W.14  14.8 ,W.15  DIFF TEMP_CELSIUS
# 0    ,W  280.0    ,W  13.0    ,W  16.5    ,W -14.0   -25.555556
# 1    ,W  310.0    ,W  13.0    ,W  17.4    ,W   4.7   -15.166667
# 2    ,W  150.0    ,W  15.2    ,W  20.1    ,W   4.5   -15.277778
# 3    ,W  290.0    ,W  14.3    ,W  17.9    ,W   4.4   -15.333333
# 4    ,W  190.0    ,W  20.6    ,W  26.8    ,W   5.2   -14.888889
#
# [5 rows x 66 columns]

# %%
selection = data[0:5]
selection
# Out:
#    USW00094724  1998-08  3.2  ,W  125.4  W  54.1 ,W.1    14 ,W.2  ...    210  \
# 0  USW00094724  1998-09  3.7  ,W  143.1  W  17.7   ,W  12.0   ,W  ...  280.0
# 1  USW00094724  1998-10  4.7  ,W  143.1  W   0.0   ,W   8.0   ,W  ...  310.0
# 2  USW00094724  1998-11  4.5  ,W  143.1  W   0.0   ,W   5.0   ,W  ...  190.0
# 3  USW00094724  1998-12  4.4  ,W  143.1  W   0.0  1,W   9.0   ,W  ...  310.0
# 4  USW00094724  1999-01  5.2  ,W    0.0  W   0.0   ,W  14.0   ,W  ...  190.0
#
#   ,W.12    200 ,W.13  11.2 ,W.14  14.8 ,W.15  DIFF TEMP_CELSIUS
# 0    ,W  280.0    ,W  13.0    ,W  16.5    ,W -14.0   -25.555556
# 1    ,W  310.0    ,W  13.0    ,W  17.4    ,W   4.7   -15.166667
# 2    ,W  150.0    ,W  15.2    ,W  20.1    ,W   4.5   -15.277778
# 3    ,W  290.0    ,W  14.3    ,W  17.9    ,W   4.4   -15.333333
# 4    ,W  190.0    ,W  20.6    ,W  26.8    ,W   5.2   -14.888889
#
# [5 rows x 66 columns]

# %%
selection = data.loc[0:5, ["DIFF", "TEMP_CELSIUS"]]
selection
# Out:
#    DIFF  TEMP_CELSIUS
# 0 -14.0    -25.555556
# 1   4.7    -15.166667
# 2   4.5    -15.277778
# 3   4.4    -15.333333
# 4   5.2    -14.888889
# 5   5.0    -15.000000

# %%
row = data.loc[4]
row
# Out:
# USW00094724     USW00094724
# 1998-08             1999-01
# 3.2                     5.2
# ,W                       ,W
# 125.4                   0.0
#                    ...
# ,W.14                    ,W
# 14.8                   26.8
# ,W.15                    ,W
# DIFF                    5.2
# TEMP_CELSIUS     -14.888889
# Name: 4, Length: 66, dtype: object

# %%
row["DIFF"]
# Out:
# 5.2

# %%
selection.at[0, "DIFF"]
# Out:
# -14.0

# %%
print(data.head())
print()
print("Value at position (1,1) is", data.iloc[1, 1])
# Out:
#    USW00094724  1998-08  3.2  ,W  125.4  W  54.1 ,W.1    14 ,W.2  ...    210  \
# 0  USW00094724  1998-09  3.7  ,W  143.1  W  17.7   ,W  12.0   ,W  ...  280.0
# 1  USW00094724  1998-10  4.7  ,W  143.1  W   0.0   ,W   8.0   ,W  ...  310.0
# 2  USW00094724  1998-11  4.5  ,W  143.1  W   0.0   ,W   5.0   ,W  ...  190.0
# 3  USW00094724  1998-12  4.4  ,W  143.1  W   0.0  1,W   9.0   ,W  ...  310.0
# 4  USW00094724  1999-01  5.2  ,W    0.0  W   0.0   ,W  14.0   ,W  ...  190.0
#
#   ,W.12    200 ,W.13  11.2 ,W.14  14.8 ,W.15  DIFF TEMP_CELSIUS
# 0    ,W  280.0    ,W  13.0    ,W  16.5    ,W -14.0   -25.555556
# 1    ,W  310.0    ,W  13.0    ,W  17.4    ,W   4.7   -15.166667
# 2    ,W  150.0    ,W  15.2    ,W  20.1    ,W   4.5   -15.277778
# 3    ,W  290.0    ,W  14.3    ,W  17.9    ,W   4.4   -15.333333
# 4    ,W  190.0    ,W  20.6    ,W  26.8    ,W   5.2   -14.888889
#
# [5 rows x 66 columns]
#
# Value at position (1,1) is 1998-10

# %%
selection = data.iloc[0:5:, 0:2]
selection
# Out:
#    USW00094724  1998-08
# 0  USW00094724  1998-09
# 1  USW00094724  1998-10
# 2  USW00094724  1998-11
# 3  USW00094724  1998-12
# 4  USW00094724  1999-01

# %%
data.iloc[-1, -1]
# Out:
# -17.88888888888889

# %%
cold_temps = data.loc[data["TEMP_CELSIUS"] < -10]
cold_temps
# Out:
#      USW00094724  1998-08  3.2   ,W  125.4    W   54.1 ,W.1    14 ,W.2  ...  \
# 0    USW00094724  1998-09  3.7   ,W  143.1    W   17.7   ,W  12.0   ,W  ...
# 1    USW00094724  1998-10  4.7   ,W  143.1    W    0.0   ,W   8.0   ,W  ...
# 2    USW00094724  1998-11  4.5   ,W  143.1    W    0.0   ,W   5.0   ,W  ...
# 3    USW00094724  1998-12  4.4   ,W  143.1    W    0.0  1,W   9.0   ,W  ...
# 4    USW00094724  1999-01  5.2   ,W    0.0    W    0.0   ,W  14.0   ,W  ...
# ..           ...      ...  ...  ...    ...  ...    ...  ...   ...  ...  ...
# 248  USW00094724  2019-06  3.7   ,W    NaN  NaN   19.4   ,W  14.0   ,W  ...
# 249  USW00094724  2019-07  3.2   ,W    NaN  NaN  123.7   ,W   6.0   ,W  ...
# 250  USW00094724  2019-08  3.3   ,W    NaN  NaN   85.6   ,W  10.0  3,W  ...
# 251  USW00094724  2019-09  3.8   ,W    NaN  NaN   13.4   ,W   9.0   ,W  ...
# 252  USW00094724  2019-10  5.1  2,W    NaN  NaN    5.3  2,W  15.0  2,W  ...
#
# ...

# %%
selection = data.loc[0:5, ["DIFF", "TEMP_CELSIUS"]].copy()
selection
# Out:
#    DIFF  TEMP_CELSIUS
# 0 -14.0    -25.555556
# 1   4.7    -15.166667
# 2   4.5    -15.277778
# 3   4.4    -15.333333
# 4   5.2    -14.888889
# 5   5.0    -15.000000

# %%
temp = selection["DIFF"]
temp
# Out:
# 0   -14.0
# 1     4.7
# 2     4.5
# 3     4.4
# 4     5.2
# 5     5.0
# Name: DIFF, dtype: float64

# %%
selection.iloc[0, 0] = 30.0
selection.head()
# Out:
#    DIFF  TEMP_CELSIUS
# 0  30.0    -25.555556
# 1   4.7    -15.166667
# 2   4.5    -15.277778
# 3   4.4    -15.333333
# 4   5.2    -14.888889

# %%
temp
# Out:
# 0    30.0
# 1     4.7
# 2     4.5
# 3     4.4
# 4     5.2
# 5     5.0
# Name: DIFF, dtype: float64
